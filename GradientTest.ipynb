# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import PIL
from PIL import Image

from gradient import calculate_matrix_python

# %%
input_matrix = np.array([
    [3, 1, 2, 4, 7],
    [5, 4, 5, 7, 10],
    [7, 6, 8, 11, 12],
    [11, 8, 10, 13, 12],
    [13, 10, 15, 14, 13]
], dtype=np.int32)
plt.imshow(input_matrix, cmap='terrain', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
result = calculate_matrix_python(input_matrix)

plt.imshow(result, cmap='plasma', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
harz = Image.open('Harz_utm.tif')
harz_arr = np.array(harz)

plt.imshow(harz_arr, cmap='terrain', interpolation='nearest')
plt.colorbar()
plt.title('Matrix Visualization')
plt.show()

# %%
harz_gradient8 = calculate_matrix_python(harz_arr)

plt.imshow(harz_gradient8, cmap='plasma', interpolation='nearest')
plt.colorbar()
plt.title('Matrix Visualization')
plt.show()
