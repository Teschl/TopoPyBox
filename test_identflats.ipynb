# %%
import topoBoxPy as topo

# %%
DEM = topo.GridObject("/home/theo/Documents/Praktikum/Harz_utm.tif")
FLATS, SILLS = DEM.identifyflats()
DEM.imageschs()
FLATS.imagesc()
SILLS.imagesc()
# FLATS.andGrid(SILLS).imagesc()
